# %% [markdown]
# <a href="https://colab.research.google.com/github/mauriciocele/understanding-deep-learning/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-46btlcpa
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-46btlcpa
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.7.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=09d357db4a161d5d85f1d6c1d26aa79136eba933d2c0d9bc80bf7b3a86b79c20
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8bjeqtbl/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303428, train error 89.68,  test loss 2.303764, test error 90.28
# Epoch   100, train loss 1.942173, train error 72.85,  test loss 1.807406, test error 71.38
# Epoch   200, train loss 1.914443, train error 71.95,  test loss 1.764150, test error 69.65
# Epoch   300, train loss 1.909058, train error 71.90,  test loss 1.755822, test error 69.32
# Epoch   400, train loss 1.907822, train error 71.47,  test loss 1.754758, test error 69.30
# Epoch   500, train loss 1.904530, train error 71.07,  test loss 1.746154, test error 69.55
# Epoch   600, train loss 1.902310, train error 71.43,  test loss 1.740294, test error 69.43
# Epoch   700, train loss 1.906513, train error 72.03,  test loss 1.759528, test error 70.90
# Epoch   800, train loss 1.902235, train error 71.20,  test loss 1.733692, test error 69.20
# Epoch   900, train loss 1.901003, train error 71.28,  test loss 1.735468, test error 69.32
# Training model with   4 hidden variables
# Epoch     0, train loss 2.304123, train error 89.97,  test loss 2.303719, test error 89.47
# Epoch   100, train loss 1.831113, train error 68.35,  test loss 1.691036, test error 66.88
# Epoch   200, train loss 1.763058, train error 63.50,  test loss 1.618628, test error 61.33
# Epoch   300, train loss 1.756323, train error 63.38,  test loss 1.621462, test error 61.42
# Epoch   400, train loss 1.755351, train error 63.17,  test loss 1.617996, test error 61.88
# Epoch   500, train loss 1.752376, train error 63.62,  test loss 1.623155, test error 61.67
# Epoch   600, train loss 1.752446, train error 62.80,  test loss 1.624829, test error 61.50
# Epoch   700, train loss 1.752468, train error 63.05,  test loss 1.626629, test error 61.65
# Epoch   800, train loss 1.750486, train error 62.90,  test loss 1.622000, test error 61.47
# Epoch   900, train loss 1.749893, train error 62.50,  test loss 1.616222, test error 62.10
# Training model with   6 hidden variables
# Epoch     0, train loss 2.262191, train error 84.38,  test loss 2.257533, test error 86.10
# Epoch   100, train loss 1.694664, train error 60.62,  test loss 1.562009, test error 60.12
# Epoch   200, train loss 1.641798, train error 58.12,  test loss 1.515892, test error 57.33
# Epoch   300, train loss 1.631149, train error 57.78,  test loss 1.502528, test error 56.60
# Epoch   400, train loss 1.622535, train error 57.12,  test loss 1.502895, test error 56.30
# Epoch   500, train loss 1.616221, train error 57.03,  test loss 1.509942, test error 57.05
# Epoch   600, train loss 1.615239, train error 56.78,  test loss 1.515885, test error 56.70
# Epoch   700, train loss 1.609610, train error 56.50,  test loss 1.511417, test error 56.90
# Epoch   800, train loss 1.609865, train error 56.60,  test loss 1.505005, test error 56.90
# Epoch   900, train loss 1.610097, train error 56.55,  test loss 1.515420, test error 57.05
# Training model with   8 hidden variables
# Epoch     0, train loss 2.295045, train error 87.05,  test loss 2.294364, test error 86.68
# Epoch   100, train loss 1.662365, train error 59.83,  test loss 1.503579, test error 57.62
# Epoch   200, train loss 1.598673, train error 57.60,  test loss 1.443001, test error 55.83
# Epoch   300, train loss 1.585779, train error 57.17,  test loss 1.448245, test error 55.95
# Epoch   400, train loss 1.570571, train error 56.00,  test loss 1.448602, test error 56.10
# Epoch   500, train loss 1.572812, train error 56.42,  test loss 1.456392, test error 56.50
# Epoch   600, train loss 1.556847, train error 55.65,  test loss 1.449705, test error 55.80
# Epoch   700, train loss 1.549892, train error 55.78,  test loss 1.458423, test error 56.88
# Epoch   800, train loss 1.548285, train error 54.90,  test loss 1.467609, test error 57.05
# Epoch   900, train loss 1.545258, train error 55.75,  test loss 1.454926, test error 56.83
# Training model with  10 hidden variables
# Epoch     0, train loss 2.284521, train error 87.35,  test loss 2.290252, test error 88.07
# Epoch   100, train loss 1.448522, train error 49.55,  test loss 1.263134, test error 46.05
# Epoch   200, train loss 1.400257, train error 46.35,  test loss 1.252788, test error 46.95
# Epoch   300, train loss 1.381105, train error 46.12,  test loss 1.251808, test error 47.15
# Epoch   400, train loss 1.373864, train error 45.88,  test loss 1.248565, test error 46.78
# Epoch   500, train loss 1.369444, train error 46.22,  test loss 1.256288, test error 46.47
# Epoch   600, train loss 1.363556, train error 45.95,  test loss 1.270488, test error 46.75
# Epoch   700, train loss 1.357581, train error 46.00,  test loss 1.273782, test error 47.03
# Epoch   800, train loss 1.357033, train error 45.72,  test loss 1.275450, test error 46.50
# Epoch   900, train loss 1.352848, train error 45.50,  test loss 1.278158, test error 46.75
# Training model with  14 hidden variables
# Epoch     0, train loss 2.200875, train error 81.97,  test loss 2.168681, test error 80.45
# Epoch   100, train loss 1.385600, train error 46.25,  test loss 1.272178, test error 47.53
# Epoch   200, train loss 1.326972, train error 44.95,  test loss 1.283734, test error 46.95
# Epoch   300, train loss 1.302355, train error 43.42,  test loss 1.313795, test error 47.53
# Epoch   400, train loss 1.275080, train error 42.58,  test loss 1.324735, test error 47.75
# Epoch   500, train loss 1.270280, train error 42.60,  test loss 1.344156, test error 48.05
# Epoch   600, train loss 1.261404, train error 41.97,  test loss 1.367661, test error 49.15
# Epoch   700, train loss 1.255810, train error 42.05,  test loss 1.368617, test error 49.08
# Epoch   800, train loss 1.248048, train error 42.40,  test loss 1.393684, test error 49.62
# Epoch   900, train loss 1.242378, train error 42.42,  test loss 1.399716, test error 48.67
# Training model with  18 hidden variables
# Epoch     0, train loss 2.229669, train error 81.78,  test loss 2.232029, test error 82.82
# Epoch   100, train loss 1.319709, train error 44.55,  test loss 1.288296, test error 48.60
# Epoch   200, train loss 1.241416, train error 42.15,  test loss 1.318320, test error 48.20
# Epoch   300, train loss 1.203258, train error 40.97,  test loss 1.370911, test error 48.60
# Epoch   400, train loss 1.170498, train error 39.20,  test loss 1.407801, test error 50.47
# Epoch   500, train loss 1.166565, train error 40.30,  test loss 1.436258, test error 51.42
# Epoch   600, train loss 1.146103, train error 38.75,  test loss 1.439000, test error 51.00
# Epoch   700, train loss 1.142370, train error 39.25,  test loss 1.457780, test error 51.47
# Epoch   800, train loss 1.129839, train error 38.30,  test loss 1.489386, test error 52.08
# Epoch   900, train loss 1.119110, train error 38.05,  test loss 1.498842, test error 51.88
# Training model with  22 hidden variables
# Epoch     0, train loss 2.174298, train error 81.50,  test loss 2.139118, test error 80.00
# Epoch   100, train loss 1.295771, train error 43.88,  test loss 1.361089, test error 51.58
# Epoch   200, train loss 1.143934, train error 38.40,  test loss 1.408214, test error 50.00
# Epoch   300, train loss 1.082695, train error 37.33,  test loss 1.500940, test error 51.35
# Epoch   400, train loss 1.040987, train error 36.30,  test loss 1.536180, test error 51.08
# Epoch   500, train loss 1.028243, train error 36.33,  test loss 1.583929, test error 51.05
# Epoch   600, train loss 1.015169, train error 34.65,  test loss 1.643278, test error 52.03
# Epoch   700, train loss 0.988637, train error 34.40,  test loss 1.678696, test error 52.28
# Epoch   800, train loss 0.985636, train error 34.25,  test loss 1.719747, test error 52.60
# Epoch   900, train loss 0.968832, train error 33.55,  test loss 1.739376, test error 52.45
# Training model with  26 hidden variables
# Epoch     0, train loss 2.124153, train error 79.65,  test loss 2.058737, test error 78.00
# Epoch   100, train loss 1.183466, train error 38.95,  test loss 1.363726, test error 49.97
# Epoch   200, train loss 1.037419, train error 34.95,  test loss 1.458822, test error 50.33
# Epoch   300, train loss 0.964216, train error 33.05,  test loss 1.578829, test error 51.33
# Epoch   400, train loss 0.930641, train error 30.85,  test loss 1.680984, test error 52.72
# Epoch   500, train loss 0.905889, train error 30.20,  test loss 1.728191, test error 52.90
# Epoch   600, train loss 0.882115, train error 28.95,  test loss 1.815332, test error 53.10
# Epoch   700, train loss 0.879181, train error 29.18,  test loss 1.940558, test error 54.58
# Epoch   800, train loss 0.862102, train error 28.95,  test loss 1.956636, test error 53.47
# Epoch   900, train loss 0.849329, train error 28.53,  test loss 2.021993, test error 54.35
# Training model with  30 hidden variables
# Epoch     0, train loss 2.202622, train error 81.25,  test loss 2.180465, test error 80.65
# Epoch   100, train loss 1.131522, train error 37.00,  test loss 1.312506, test error 47.75
# Epoch   200, train loss 0.933072, train error 30.72,  test loss 1.500793, test error 50.38
# Epoch   300, train loss 0.835570, train error 27.35,  test loss 1.653087, test error 51.42
# Epoch   400, train loss 0.767067, train error 24.32,  test loss 1.770666, test error 51.17
# Epoch   500, train loss 0.755459, train error 25.53,  test loss 1.974395, test error 53.15
# Epoch   600, train loss 0.721558, train error 23.95,  test loss 2.066694, test error 52.67
# Epoch   700, train loss 0.690707, train error 23.68,  test loss 2.203025, test error 52.92
# Epoch   800, train loss 0.665691, train error 22.20,  test loss 2.370848, test error 53.95
# Epoch   900, train loss 0.677451, train error 23.40,  test loss 2.508376, test error 54.75
# Training model with  35 hidden variables
# Epoch     0, train loss 2.135198, train error 78.45,  test loss 2.091690, test error 78.15
# Epoch   100, train loss 1.005242, train error 32.65,  test loss 1.427024, test error 49.53
# Epoch   200, train loss 0.775260, train error 25.12,  test loss 1.745527, test error 52.88
# Epoch   300, train loss 0.651617, train error 20.90,  test loss 2.120094, test error 53.58
# Epoch   400, train loss 0.605421, train error 20.28,  test loss 2.537021, test error 55.33
# Epoch   500, train loss 0.538524, train error 17.57,  test loss 2.870053, test error 55.47
# Epoch   600, train loss 0.516718, train error 17.20,  test loss 3.164402, test error 55.97
# Epoch   700, train loss 0.469712, train error 15.57,  test loss 3.491353, test error 56.62
# Epoch   800, train loss 0.444569, train error 14.95,  test loss 3.845906, test error 56.67
# Epoch   900, train loss 0.426570, train error 14.20,  test loss 4.136221, test error 56.62
# Training model with  40 hidden variables
# Epoch     0, train loss 2.099428, train error 77.12,  test loss 2.065598, test error 77.88
# Epoch   100, train loss 0.897505, train error 29.12,  test loss 1.421596, test error 48.72
# Epoch   200, train loss 0.630013, train error 19.95,  test loss 1.971593, test error 52.42
# Epoch   300, train loss 0.457827, train error 14.57,  test loss 2.707632, test error 53.40
# Epoch   400, train loss 0.394407, train error 12.80,  test loss 3.485670, test error 54.78
# Epoch   500, train loss 0.313290, train error 10.32,  test loss 4.306818, test error 55.88
# Epoch   600, train loss 0.273524, train error 9.28,  test loss 5.063077, test error 55.97
# Epoch   700, train loss 0.256817, train error 8.70,  test loss 5.864519, test error 56.85
# Epoch   800, train loss 0.208243, train error 7.12,  test loss 6.491740, test error 56.53
# Epoch   900, train loss 0.240300, train error 8.32,  test loss 7.150900, test error 56.62
# Training model with  45 hidden variables
# Epoch     0, train loss 2.133275, train error 78.95,  test loss 2.097173, test error 77.65
# Epoch   100, train loss 0.858102, train error 27.35,  test loss 1.443088, test error 47.80
# Epoch   200, train loss 0.520980, train error 16.38,  test loss 2.078617, test error 50.47
# Epoch   300, train loss 0.331005, train error 9.30,  test loss 3.041045, test error 52.75
# Epoch   400, train loss 0.220488, train error 6.38,  test loss 4.159237, test error 54.12
# Epoch   500, train loss 0.156309, train error 4.53,  test loss 5.463468, test error 55.25
# Epoch   600, train loss 0.161323, train error 5.47,  test loss 6.691968, test error 55.12
# Epoch   700, train loss 0.018976, train error 0.05,  test loss 7.830684, test error 55.45
# Epoch   800, train loss 0.010188, train error 0.00,  test loss 8.653700, test error 55.62
# Epoch   900, train loss 0.007201, train error 0.00,  test loss 9.237014, test error 55.67
# Training model with  50 hidden variables
# Epoch     0, train loss 2.083650, train error 76.82,  test loss 2.048761, test error 77.55
# Epoch   100, train loss 0.714519, train error 21.78,  test loss 1.617796, test error 50.58
# Epoch   200, train loss 0.347451, train error 10.40,  test loss 2.769966, test error 54.12
# Epoch   300, train loss 0.158549, train error 3.85,  test loss 4.348748, test error 55.60
# Epoch   400, train loss 0.031698, train error 0.00,  test loss 5.984671, test error 56.17
# Epoch   500, train loss 0.014367, train error 0.00,  test loss 7.053431, test error 56.58
# Epoch   600, train loss 0.008931, train error 0.00,  test loss 7.729271, test error 56.50
# Epoch   700, train loss 0.006375, train error 0.00,  test loss 8.249605, test error 56.55
# Epoch   800, train loss 0.004870, train error 0.00,  test loss 8.656513, test error 56.47
# Epoch   900, train loss 0.003933, train error 0.00,  test loss 8.999242, test error 56.60
# Training model with  55 hidden variables
# Epoch     0, train loss 2.037519, train error 75.68,  test loss 1.980545, test error 75.25
# Epoch   100, train loss 0.602631, train error 17.72,  test loss 1.675389, test error 50.62
# Epoch   200, train loss 0.219249, train error 5.25,  test loss 3.201502, test error 54.80
# Epoch   300, train loss 0.039462, train error 0.12,  test loss 5.024319, test error 55.30
# Epoch   400, train loss 0.014318, train error 0.00,  test loss 6.117051, test error 56.22
# Epoch   500, train loss 0.008290, train error 0.00,  test loss 6.769066, test error 56.28
# Epoch   600, train loss 0.005716, train error 0.00,  test loss 7.238967, test error 56.25
# Epoch   700, train loss 0.004283, train error 0.00,  test loss 7.605851, test error 56.30
# Epoch   800, train loss 0.003394, train error 0.00,  test loss 7.897511, test error 56.25
# Epoch   900, train loss 0.002788, train error 0.00,  test loss 8.151036, test error 56.30
# Training model with  60 hidden variables
# Epoch     0, train loss 2.060508, train error 77.97,  test loss 1.999678, test error 76.05
# Epoch   100, train loss 0.542451, train error 15.93,  test loss 1.811782, test error 52.60
# Epoch   200, train loss 0.105536, train error 1.07,  test loss 3.511104, test error 55.20
# Epoch   300, train loss 0.018834, train error 0.00,  test loss 4.989996, test error 55.38
# Epoch   400, train loss 0.009211, train error 0.00,  test loss 5.734358, test error 56.00
# Epoch   500, train loss 0.005780, train error 0.00,  test loss 6.209454, test error 55.70
# Epoch   600, train loss 0.004104, train error 0.00,  test loss 6.565675, test error 55.72
# Epoch   700, train loss 0.003149, train error 0.00,  test loss 6.846624, test error 55.78
# Epoch   800, train loss 0.002538, train error 0.00,  test loss 7.079055, test error 55.85
# Epoch   900, train loss 0.002112, train error 0.00,  test loss 7.280097, test error 55.90
# Training model with  70 hidden variables
# Epoch     0, train loss 2.031875, train error 75.07,  test loss 1.988920, test error 76.00
# Epoch   100, train loss 0.329472, train error 7.82,  test loss 1.972915, test error 50.20
# Epoch   200, train loss 0.028265, train error 0.00,  test loss 3.582461, test error 52.42
# Epoch   300, train loss 0.010027, train error 0.00,  test loss 4.304280, test error 52.35
# Epoch   400, train loss 0.005725, train error 0.00,  test loss 4.720700, test error 52.72
# Epoch   500, train loss 0.003894, train error 0.00,  test loss 5.016060, test error 52.70
# Epoch   600, train loss 0.002899, train error 0.00,  test loss 5.239454, test error 52.65
# Epoch   700, train loss 0.002284, train error 0.00,  test loss 5.421006, test error 52.62
# Epoch   800, train loss 0.001871, train error 0.00,  test loss 5.573201, test error 52.67
# Epoch   900, train loss 0.001575, train error 0.00,  test loss 5.706007, test error 52.62
# Training model with  80 hidden variables
# Epoch     0, train loss 2.011182, train error 74.75,  test loss 1.927890, test error 74.45
# Epoch   100, train loss 0.245230, train error 4.90,  test loss 2.107919, test error 52.88
# Epoch   200, train loss 0.019704, train error 0.00,  test loss 3.476719, test error 52.20
# Epoch   300, train loss 0.007955, train error 0.00,  test loss 4.058498, test error 52.53
# Epoch   400, train loss 0.004679, train error 0.00,  test loss 4.390586, test error 52.38
# Epoch   500, train loss 0.003248, train error 0.00,  test loss 4.633788, test error 52.60
# Epoch   600, train loss 0.002444, train error 0.00,  test loss 4.822118, test error 52.67
# Epoch   700, train loss 0.001943, train error 0.00,  test loss 4.976054, test error 52.60
# Epoch   800, train loss 0.001600, train error 0.00,  test loss 5.104980, test error 52.65
# Epoch   900, train loss 0.001354, train error 0.00,  test loss 5.217184, test error 52.70
# Training model with  90 hidden variables
# Epoch     0, train loss 1.993001, train error 73.80,  test loss 1.935104, test error 75.47
# Epoch   100, train loss 0.140106, train error 1.03,  test loss 2.213775, test error 52.58
# Epoch   200, train loss 0.014701, train error 0.00,  test loss 3.303772, test error 53.12
# Epoch   300, train loss 0.006444, train error 0.00,  test loss 3.742938, test error 53.20
# Epoch   400, train loss 0.003946, train error 0.00,  test loss 4.014749, test error 53.20
# Epoch   500, train loss 0.002771, train error 0.00,  test loss 4.208529, test error 53.08
# Epoch   600, train loss 0.002110, train error 0.00,  test loss 4.363649, test error 53.00
# Epoch   700, train loss 0.001686, train error 0.00,  test loss 4.488909, test error 53.10
# Epoch   800, train loss 0.001397, train error 0.00,  test loss 4.595610, test error 53.22
# Epoch   900, train loss 0.001187, train error 0.00,  test loss 4.687557, test error 53.20
# Training model with 100 hidden variables
# Epoch     0, train loss 1.989701, train error 74.53,  test loss 1.919516, test error 73.82
# Epoch   100, train loss 0.090659, train error 0.22,  test loss 2.254328, test error 51.80
# Epoch   200, train loss 0.011951, train error 0.00,  test loss 3.082754, test error 52.08
# Epoch   300, train loss 0.005586, train error 0.00,  test loss 3.444815, test error 51.97
# Epoch   400, train loss 0.003487, train error 0.00,  test loss 3.665234, test error 52.28
# Epoch   500, train loss 0.002480, train error 0.00,  test loss 3.828498, test error 52.10
# Epoch   600, train loss 0.001901, train error 0.00,  test loss 3.954898, test error 52.10
# Epoch   700, train loss 0.001528, train error 0.00,  test loss 4.060676, test error 52.00
# Epoch   800, train loss 0.001269, train error 0.00,  test loss 4.149128, test error 52.00
# Epoch   900, train loss 0.001081, train error 0.00,  test loss 4.226689, test error 51.97
# Training model with 120 hidden variables
# Epoch     0, train loss 1.962441, train error 72.65,  test loss 1.908142, test error 73.72
# Epoch   100, train loss 0.055006, train error 0.00,  test loss 2.313686, test error 51.62
# Epoch   200, train loss 0.009552, train error 0.00,  test loss 2.945572, test error 51.33
# Epoch   300, train loss 0.004707, train error 0.00,  test loss 3.240243, test error 51.42
# Epoch   400, train loss 0.003010, train error 0.00,  test loss 3.427896, test error 51.47
# Epoch   500, train loss 0.002165, train error 0.00,  test loss 3.563862, test error 51.50
# Epoch   600, train loss 0.001672, train error 0.00,  test loss 3.672452, test error 51.47
# Epoch   700, train loss 0.001351, train error 0.00,  test loss 3.763432, test error 51.58
# Epoch   800, train loss 0.001127, train error 0.00,  test loss 3.840014, test error 51.45
# Epoch   900, train loss 0.000963, train error 0.00,  test loss 3.906724, test error 51.40
# Training model with 140 hidden variables
# Epoch     0, train loss 1.972057, train error 72.95,  test loss 1.910171, test error 72.82
# Epoch   100, train loss 0.036794, train error 0.00,  test loss 2.239892, test error 50.20
# Epoch   200, train loss 0.008100, train error 0.00,  test loss 2.737087, test error 50.40
# Epoch   300, train loss 0.004148, train error 0.00,  test loss 2.973416, test error 50.17
# Epoch   400, train loss 0.002689, train error 0.00,  test loss 3.125038, test error 50.33
# Epoch   500, train loss 0.001955, train error 0.00,  test loss 3.238503, test error 50.22
# Epoch   600, train loss 0.001519, train error 0.00,  test loss 3.330372, test error 50.12
# Epoch   700, train loss 0.001234, train error 0.00,  test loss 3.405582, test error 50.15
# Epoch   800, train loss 0.001033, train error 0.00,  test loss 3.469305, test error 50.17
# Epoch   900, train loss 0.000885, train error 0.00,  test loss 3.525696, test error 50.17
# Training model with 160 hidden variables
# Epoch     0, train loss 1.932377, train error 70.93,  test loss 1.853004, test error 70.85
# Epoch   100, train loss 0.028999, train error 0.00,  test loss 2.057042, test error 48.53
# Epoch   200, train loss 0.007203, train error 0.00,  test loss 2.442671, test error 48.78
# Epoch   300, train loss 0.003790, train error 0.00,  test loss 2.634365, test error 48.70
# Epoch   400, train loss 0.002482, train error 0.00,  test loss 2.761927, test error 48.80
# Epoch   500, train loss 0.001817, train error 0.00,  test loss 2.856164, test error 48.78
# Epoch   600, train loss 0.001419, train error 0.00,  test loss 2.933082, test error 48.83
# Epoch   700, train loss 0.001155, train error 0.00,  test loss 2.996568, test error 48.88
# Epoch   800, train loss 0.000970, train error 0.00,  test loss 3.050835, test error 48.90
# Epoch   900, train loss 0.000833, train error 0.00,  test loss 3.098181, test error 48.88
# Training model with 180 hidden variables
# Epoch     0, train loss 1.948732, train error 72.28,  test loss 1.868275, test error 73.22
# Epoch   100, train loss 0.024674, train error 0.00,  test loss 2.106205, test error 49.60
# Epoch   200, train loss 0.006663, train error 0.00,  test loss 2.477925, test error 49.72
# Epoch   300, train loss 0.003558, train error 0.00,  test loss 2.660529, test error 49.60
# Epoch   400, train loss 0.002356, train error 0.00,  test loss 2.786007, test error 49.33
# Epoch   500, train loss 0.001734, train error 0.00,  test loss 2.876969, test error 49.40
# Epoch   600, train loss 0.001358, train error 0.00,  test loss 2.950872, test error 49.28
# Epoch   700, train loss 0.001109, train error 0.00,  test loss 3.012611, test error 49.35
# Epoch   800, train loss 0.000933, train error 0.00,  test loss 3.065185, test error 49.30
# Epoch   900, train loss 0.000802, train error 0.00,  test loss 3.111273, test error 49.33
# Training model with 200 hidden variables
# Epoch     0, train loss 1.934605, train error 71.32,  test loss 1.856525, test error 72.50
# Epoch   100, train loss 0.022190, train error 0.00,  test loss 1.985205, test error 47.58
# Epoch   200, train loss 0.006240, train error 0.00,  test loss 2.298170, test error 47.38
# Epoch   300, train loss 0.003381, train error 0.00,  test loss 2.461189, test error 47.62
# Epoch   400, train loss 0.002252, train error 0.00,  test loss 2.569787, test error 47.75
# Epoch   500, train loss 0.001663, train error 0.00,  test loss 2.651368, test error 47.67
# Epoch   600, train loss 0.001305, train error 0.00,  test loss 2.718818, test error 47.72
# Epoch   700, train loss 0.001067, train error 0.00,  test loss 2.773503, test error 47.78
# Epoch   800, train loss 0.000899, train error 0.00,  test loss 2.821209, test error 47.67
# Epoch   900, train loss 0.000773, train error 0.00,  test loss 2.862657, test error 47.70
# Training model with 250 hidden variables
# Epoch     0, train loss 1.925009, train error 69.55,  test loss 1.832878, test error 70.40
# Epoch   100, train loss 0.016867, train error 0.00,  test loss 1.886686, test error 46.45
# Epoch   200, train loss 0.005321, train error 0.00,  test loss 2.138766, test error 46.10
# Epoch   300, train loss 0.002969, train error 0.00,  test loss 2.273744, test error 46.20
# Epoch   400, train loss 0.002009, train error 0.00,  test loss 2.364484, test error 46.33
# Epoch   500, train loss 0.001497, train error 0.00,  test loss 2.434733, test error 46.15
# Epoch   600, train loss 0.001183, train error 0.00,  test loss 2.490402, test error 46.22
# Epoch   700, train loss 0.000971, train error 0.00,  test loss 2.537245, test error 46.20
# Epoch   800, train loss 0.000821, train error 0.00,  test loss 2.577832, test error 46.22
# Epoch   900, train loss 0.000708, train error 0.00,  test loss 2.613268, test error 46.22
# Training model with 300 hidden variables
# Epoch     0, train loss 1.889209, train error 67.95,  test loss 1.812150, test error 70.35
# Epoch   100, train loss 0.014341, train error 0.00,  test loss 1.829736, test error 45.45
# Epoch   200, train loss 0.004761, train error 0.00,  test loss 2.038841, test error 45.20
# Epoch   300, train loss 0.002706, train error 0.00,  test loss 2.155773, test error 45.05
# Epoch   400, train loss 0.001840, train error 0.00,  test loss 2.235214, test error 45.12
# Epoch   500, train loss 0.001377, train error 0.00,  test loss 2.295952, test error 45.05
# Epoch   600, train loss 0.001091, train error 0.00,  test loss 2.345482, test error 45.17
# Epoch   700, train loss 0.000898, train error 0.00,  test loss 2.386600, test error 45.17
# Epoch   800, train loss 0.000760, train error 0.00,  test loss 2.422174, test error 45.20
# Epoch   900, train loss 0.000657, train error 0.00,  test loss 2.452928, test error 45.28
# Training model with 400 hidden variables
# Epoch     0, train loss 1.855779, train error 66.65,  test loss 1.783626, test error 69.43
# Epoch   100, train loss 0.011527, train error 0.00,  test loss 1.771092, test error 46.00
# Epoch   200, train loss 0.004112, train error 0.00,  test loss 1.948126, test error 45.58
# Epoch   300, train loss 0.002383, train error 0.00,  test loss 2.048312, test error 45.67
# Epoch   400, train loss 0.001642, train error 0.00,  test loss 2.117408, test error 45.55
# Epoch   500, train loss 0.001237, train error 0.00,  test loss 2.170303, test error 45.38
# Epoch   600, train loss 0.000985, train error 0.00,  test loss 2.212590, test error 45.33
# Epoch   700, train loss 0.000814, train error 0.00,  test loss 2.248635, test error 45.40
# Epoch   800, train loss 0.000691, train error 0.00,  test loss 2.279535, test error 45.30
# Epoch   900, train loss 0.000598, train error 0.00,  test loss 2.307248, test error 45.20

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
